# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Out:
# /tmp/ipykernel_22614/3615006263.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
accidents = pd.read_csv('./data/Accidents.txt', sep='\t', encoding = "ISO-8859-1")

# %%
accidents.head()
# Out:
#      AccidentId    Gravity        Date      Hour     Light  Department  \
# 0  201800000001  NonLethal  2018-01-24  15:05:00  Daylight         590
# 1  201800000002  NonLethal  2018-02-12  10:15:00  Daylight         590
# 2  201800000003  NonLethal  2018-03-04  11:35:00  Daylight         590
# 3  201800000004  NonLethal  2018-05-05  17:35:00  Daylight         590
# 4  201800000005  NonLethal  2018-06-26  16:05:00  Daylight         590
#
#    Commune InAgglomeration IntersectionType   Weather  \
# 0        5              No           Y-type    Normal
# 1       11             Yes           Square  VeryGood
# 2      477             Yes           T-type    Normal
# 3       52             Yes   NoIntersection  VeryGood
# 4      477             Yes   NoIntersection    Normal
#
#                       CollisionType             PostalAddress
# 0  2Vehicles-BehindVehicles-Frontal    route des Ansereuilles
# 1                       NoCollision  Place du général de Gaul
# 2                       NoCollision            Rue  nationale
# 3                    2Vehicles-Side       30 rue Jules Guesde
# 4                    2Vehicles-Side        72 rue Victor Hugo

# %%
users = pd.read_csv('./data/Users.txt', sep='\t', encoding = "ISO-8859-1")

# %%
users.head()
# Out:
#      AccidentId VehicleId  Seat    Category                 Gravity Gender  \
# 0  201800000001       A01   1.0      Driver               Unscathed   Male
# 1  201800000001       B01   1.0      Driver  InjuredAndHospitalized   Male
# 2  201800000002       A01   1.0      Driver               Unscathed   Male
# 3  201800000002       A01   NaN  Pedestrian           MildlyInjured   Male
# 4  201800000003       A01   1.0      Driver  InjuredAndHospitalized   Male
#
#   TripReason SafetyDevice SafetyDeviceUsed            PedestrianLocation  \
# 0    Leisure     SeatBelt              Yes                           NaN
# 1        NaN     SeatBelt              Yes                           NaN
# 2        NaN     SeatBelt              Yes                           NaN
# 3        NaN       Helmet              NaN  OnLane<=OnSidewalk0mCrossing
# 4    Leisure       Helmet              Yes                           NaN
#
#   PedestrianAction PedestrianCompany  BirthYear
# 0              NaN           Unknown     1960.0
# 1              NaN           Unknown     1928.0
# 2              NaN           Unknown     1947.0
# 3         Crossing             Alone     1959.0
# 4              NaN           Unknown     1987.0

# %%
users.describe(include='all')
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130169 entries, 0 to 130168
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   AccidentId          130169 non-null  int64
#  1   VehicleId           130169 non-null  object
#  2   Seat                119209 non-null  float64
#  3   Category            130169 non-null  object
#  4   Gravity             130169 non-null  object
#  5   Gender              130169 non-null  object
#  6   TripReason          101713 non-null  object
#  7   SafetyDevice        126040 non-null  object
#  8   SafetyDeviceUsed    116075 non-null  object
#  9   PedestrianLocation  10043 non-null   object
#  10  PedestrianAction    10303 non-null   object
#  11  PedestrianCompany   75523 non-null   object
#  12  BirthYear           130139 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 12.9+ MB

# %%
df = pd.read_csv('./src/processed/merged_data.csv')

# %%
df.head()
# Out:
#      AccidentId VehicleId  Seat  Category_x               Gravity_x Gender  \
# 0  201800000001       A01   1.0      Driver               Unscathed   Male
# 1  201800000001       B01   1.0      Driver  InjuredAndHospitalized   Male
# 2  201800000002       A01   1.0      Driver               Unscathed   Male
# 3  201800000002       A01   NaN  Pedestrian           MildlyInjured   Male
# 4  201800000003       A01   1.0      Driver  InjuredAndHospitalized   Male
#
#   TripReason SafetyDevice SafetyDeviceUsed            PedestrianLocation  ...  \
# 0    Leisure     SeatBelt              Yes                           NaN  ...
# 1        NaN     SeatBelt              Yes                           NaN  ...
# 2        NaN     SeatBelt              Yes                           NaN  ...
# 3        NaN       Helmet              NaN  OnLane<=OnSidewalk0mCrossing  ...
# 4    Leisure       Helmet              Yes                           NaN  ...
#
#     Weather                     CollisionType             PostalAddress  \
# 0    Normal  2Vehicles-BehindVehicles-Frontal    route des Ansereuilles
# 1    Normal  2Vehicles-BehindVehicles-Frontal    route des Ansereuilles
# 2  VeryGood                       NoCollision  Place du général de Gaul
# 3  VeryGood                       NoCollision  Place du général de Gaul
# 4    Normal                       NoCollision            Rue  nationale
#
#   Direction        Category_y PassengerNumber      FixedObstacle  \
# 0   Unknown         Car<=3.5T               0                NaN
# 1   Unknown         Car<=3.5T               0                NaN
# 2   Unknown         Car<=3.5T               0                NaN
# 3   Unknown         Car<=3.5T               0                NaN
# 4   Unknown  Motorbike>125cm3               0  StationaryVehicle
#
#    MobileObstacle  ImpactPoint           Maneuver
# 0         Vehicle   RightFront         TurnToLeft
# 1         Vehicle    LeftFront  NoDirectionChange
# 2      Pedestrian          NaN  NoDirectionChange
# 3      Pedestrian          NaN  NoDirectionChange
# 4         Vehicle        Front  NoDirectionChange
#
# [5 rows x 31 columns]

# %% [markdown]
# # preprocessing and model

# %% [markdown]
# On veut predire l'attribut ``` Gravity_x ``` à partir de toutes les autres attributs

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.impute import SimpleImputer

# %%
y = df['Gravity_x']
X = df.drop(['Gravity_x', 'Gravity_y', 'AccidentId', 'VehicleId'], axis=1)

# %%
cat_values = X.select_dtypes(include='object').columns

# %%
for cat in cat_values:
    X[cat] = LabelEncoder().fit_transform(X[cat])

# %%
num_imputer = SimpleImputer(strategy='constant', fill_value=-1)

# %%
preprocessor = ColumnTransformer(
transformers=[
('num', num_imputer, X.columns)]
)

# %%
model1 = RandomForestClassifier()
model2 = HistGradientBoostingClassifier()

# %%
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
('model', model1)
])

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
cross_val_score(my_pipeline, X, y, cv=cv, scoring='balanced_accuracy')
# Out:
# array([0.47662054, 0.47997184, 0.47921476, 0.4803315 , 0.4790923 ])
